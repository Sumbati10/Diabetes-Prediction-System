# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#importing-the-libraries" data-toc-modified-id="importing-the-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>importing the libraries</a></span></li><li><span><a href="#Plot-settings" data-toc-modified-id="Plot-settings-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Plot settings</a></span></li><li><span><a href="#Reading-the-data" data-toc-modified-id="Reading-the-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Reading the data</a></span></li><li><span><a href="#Exploratory-data-analysis-(EDA)" data-toc-modified-id="Exploratory-data-analysis-(EDA)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exploratory data analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Dashboard-with-sweetviz" data-toc-modified-id="Dashboard-with-sweetviz-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Dashboard with sweetviz</a></span></li><li><span><a href="#Pairplot-of-the-all-the-features" data-toc-modified-id="Pairplot-of-the-all-the-features-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Pairplot of the all the features</a></span></li><li><span><a href="#Pearson-correlation-and-feature-selection" data-toc-modified-id="Pearson-correlation-and-feature-selection-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Pearson correlation and feature selection</a></span></li><li><span><a href="#Class-distribution-in-Diabetes-dataset" data-toc-modified-id="Class-distribution-in-Diabetes-dataset-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Class distribution in Diabetes dataset</a></span></li></ul></li><li><span><a href="#Preparing-data-for-machine-learning" data-toc-modified-id="Preparing-data-for-machine-learning-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Preparing data for machine learning</a></span></li><li><span><a href="#Machine-learning-Models" data-toc-modified-id="Machine-learning-Models-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Machine learning Models</a></span><ul class="toc-item"><li><span><a href="#k-Nearest-Neighbors-(KNN)" data-toc-modified-id="k-Nearest-Neighbors-(KNN)-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>k-Nearest Neighbors (KNN)</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>K-fold cross validation</a></span></li></ul></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>K-fold cross validation</a></span></li></ul></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Decision Tree</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>K-fold cross validation</a></span></li><li><span><a href="#Feature-importance-in-Decision-trees" data-toc-modified-id="Feature-importance-in-Decision-trees-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Feature importance in Decision trees</a></span></li></ul></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Random Forest</a></span><ul class="toc-item"><li><span><a href="#Feature-importance-in-Random-Forest" data-toc-modified-id="Feature-importance-in-Random-Forest-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Feature importance in Random Forest</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Gradient Boosting</a></span><ul class="toc-item"><li><span><a href="#Feature-importance-in-Gradient-Boosting" data-toc-modified-id="Feature-importance-in-Gradient-Boosting-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Feature importance in Gradient Boosting</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.5.2"><span class="toc-item-num">7.5.2&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.5.3"><span class="toc-item-num">7.5.3&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#Support-Vector-Machine-(SVM)" data-toc-modified-id="Support-Vector-Machine-(SVM)-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Support Vector Machine (SVM)</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.6.1"><span class="toc-item-num">7.6.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.6.2"><span class="toc-item-num">7.6.2&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#Neural-Networks" data-toc-modified-id="Neural-Networks-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Neural Networks</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.7.1"><span class="toc-item-num">7.7.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.7.2"><span class="toc-item-num">7.7.2&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li></ul></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-7.8"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>XGBoost</a></span><ul class="toc-item"><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-7.8.1"><span class="toc-item-num">7.8.1&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#K-fold-cross-validation" data-toc-modified-id="K-fold-cross-validation-7.8.2"><span class="toc-item-num">7.8.2&nbsp;&nbsp;</span>K-fold cross-validation</a></span></li><li><span><a href="#Feature-importance-in-XGBoost" data-toc-modified-id="Feature-importance-in-XGBoost-7.8.3"><span class="toc-item-num">7.8.3&nbsp;&nbsp;</span>Feature importance in XGBoost</a></span></li></ul></li></ul></li><li><span><a href="#Model-comparision" data-toc-modified-id="Model-comparision-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Model comparision</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#In-Future" data-toc-modified-id="In-Future-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>In Future</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# **Understanding and predicting of diabetes based of medical conditions**.

# %% [markdown]
# # importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sweetviz as sv
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix


# %matplotlib inline

# %% [markdown]
# # Plot settings

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 23
plt.rcParams['figure.titlesize'] = 26
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
plt.rcParams['figure.figsize'] = 7,4
sns.set_style('ticks')

# %% [markdown]
# # Reading the data

# %%
csv_file='diabetes.csv'
df = pd.read_csv(csv_file)

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.iloc[:,:-1].describe().style.background_gradient(axis=0,cmap='Accent')
# Out:
# <style type="text/css">
# #T_d6465_row0_col0, #T_d6465_row0_col1, #T_d6465_row0_col2, #T_d6465_row0_col3, #T_d6465_row0_col4, #T_d6465_row0_col5, #T_d6465_row0_col6, #T_d6465_row0_col7, #T_d6465_row7_col4 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_d6465_row1_col0, #T_d6465_row1_col2, #T_d6465_row1_col3, #T_d6465_row1_col4, #T_d6465_row1_col5, #T_d6465_row1_col6, #T_d6465_row1_col7, #T_d6465_row2_col0, #T_d6465_row2_col1, #T_d6465_row2_col2, #T_d6465_row2_col3, #T_d6465_row2_col5, #T_d6465_row2_col6, #T_d6465_row2_col7, #T_d6465_row3_col0, #T_d6465_row3_col1, #T_d6465_row3_col2, #T_d6465_row3_col3, #T_d6465_row3_col4, #T_d6465_row3_col5, #T_d6465_row3_col6, #T_d6465_row3_col7, #T_d6465_row4_col0, #T_d6465_row4_col2, #T_d6465_row4_col3, #T_d6465_row4_col4, #T_d6465_row4_col5, #T_d6465_row4_col6, #T_d6465_row4_col7, #T_d6465_row5_col0, #T_d6465_row5_col2, #T_d6465_row5_col3, #T_d6465_row5_col4, #T_d6465_row5_col5, #T_d6465_row5_col6, #T_d6465_row5_col7, #T_d6465_row6_col0, #T_d6465_row6_col2, #T_d6465_row6_col3, #T_d6465_row6_col5, #T_d6465_row6_col6, #T_d6465_row6_col7, #T_d6465_row7_col0, #T_d6465_row7_col5, #T_d6465_row7_col6, #T_d6465_row7_col7 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_d6465_row1_col1, #T_d6465_row2_col4, #T_d6465_row4_col1, #T_d6465_row5_col1, #T_d6465_row6_col1, #T_d6465_row6_col4, #T_d6465_row7_col2, #T_d6465_row7_col3 {
#   background-color: #beaed4;
#   color: #000000;
# }
# #T_d6465_row7_col1 {
#   background-color: #fdc086;
#   color: #000000;
# }
# </style>
# <table id="T_d6465">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6465_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_d6465_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_d6465_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_d6465_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_d6465_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_d6465_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_d6465_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_d6465_level0_col7" class="col_heading level0 col7" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6465_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d6465_row0_col0" class="data row0 col0" >768.000000</td>
#       <td id="T_d6465_row0_col1" class="data row0 col1" >768.000000</td>
#       <td id="T_d6465_row0_col2" class="data row0 col2" >768.000000</td>
#       <td id="T_d6465_row0_col3" class="data row0 col3" >768.000000</td>
#       <td id="T_d6465_row0_col4" class="data row0 col4" >768.000000</td>
#       <td id="T_d6465_row0_col5" class="data row0 col5" >768.000000</td>
#       <td id="T_d6465_row0_col6" class="data row0 col6" >768.000000</td>
#       <td id="T_d6465_row0_col7" class="data row0 col7" >768.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6465_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_d6465_row1_col0" class="data row1 col0" >3.845052</td>
#       <td id="T_d6465_row1_col1" class="data row1 col1" >120.894531</td>
#       <td id="T_d6465_row1_col2" class="data row1 col2" >69.105469</td>
#       <td id="T_d6465_row1_col3" class="data row1 col3" >20.536458</td>
#       <td id="T_d6465_row1_col4" class="data row1 col4" >79.799479</td>
#       <td id="T_d6465_row1_col5" class="data row1 col5" >31.992578</td>
#       <td id="T_d6465_row1_col6" class="data row1 col6" >0.471876</td>
#       <td id="T_d6465_row1_col7" class="data row1 col7" >33.240885</td>
#     </tr>
#     <tr>
#       <th id="T_d6465_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_d6465_row2_col0" class="data row2 col0" >3.369578</td>
#       <td id="T_d6465_row2_col1" class="data row2 col1" >31.972618</td>
#       <td id="T_d6465_row2_col2" class="data row2 col2" >19.355807</td>
#       <td id="T_d6465_row2_col3" class="data row2 col3" >15.952218</td>
#       <td id="T_d6465_row2_col4" class="data row2 col4" >115.244002</td>
#       <td id="T_d6465_row2_col5" class="data row2 col5" >7.884160</td>
#       <td id="T_d6465_row2_col6" class="data row2 col6" >0.331329</td>
#       <td id="T_d6465_row2_col7" class="data row2 col7" >11.760232</td>
#     </tr>
#     <tr>
#       <th id="T_d6465_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_d6465_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_d6465_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_d6465_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_d6465_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_d6465_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_d6465_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_d6465_row3_col6" class="data row3 col6" >0.078000</td>
#       <td id="T_d6465_row3_col7" class="data row3 col7" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6465_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_d6465_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_d6465_row4_col1" class="data row4 col1" >99.000000</td>
#       <td id="T_d6465_row4_col2" class="data row4 col2" >62.000000</td>
#       <td id="T_d6465_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_d6465_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_d6465_row4_col5" class="data row4 col5" >27.300000</td>
#       <td id="T_d6465_row4_col6" class="data row4 col6" >0.243750</td>
#       <td id="T_d6465_row4_col7" class="data row4 col7" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6465_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_d6465_row5_col0" class="data row5 col0" >3.000000</td>
#       <td id="T_d6465_row5_col1" class="data row5 col1" >117.000000</td>
#       <td id="T_d6465_row5_col2" class="data row5 col2" >72.000000</td>
#       <td id="T_d6465_row5_col3" class="data row5 col3" >23.000000</td>
#       <td id="T_d6465_row5_col4" class="data row5 col4" >30.500000</td>
#       <td id="T_d6465_row5_col5" class="data row5 col5" >32.000000</td>
#       <td id="T_d6465_row5_col6" class="data row5 col6" >0.372500</td>
#       <td id="T_d6465_row5_col7" class="data row5 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6465_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_d6465_row6_col0" class="data row6 col0" >6.000000</td>
#       <td id="T_d6465_row6_col1" class="data row6 col1" >140.250000</td>
#       <td id="T_d6465_row6_col2" class="data row6 col2" >80.000000</td>
#       <td id="T_d6465_row6_col3" class="data row6 col3" >32.000000</td>
#       <td id="T_d6465_row6_col4" class="data row6 col4" >127.250000</td>
#       <td id="T_d6465_row6_col5" class="data row6 col5" >36.600000</td>
#       <td id="T_d6465_row6_col6" class="data row6 col6" >0.626250</td>
#       <td id="T_d6465_row6_col7" class="data row6 col7" >41.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6465_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_d6465_row7_col0" class="data row7 col0" >17.000000</td>
#       <td id="T_d6465_row7_col1" class="data row7 col1" >199.000000</td>
#       <td id="T_d6465_row7_col2" class="data row7 col2" >122.000000</td>
#       <td id="T_d6465_row7_col3" class="data row7 col3" >99.000000</td>
#       <td id="T_d6465_row7_col4" class="data row7 col4" >846.000000</td>
#       <td id="T_d6465_row7_col5" class="data row7 col5" >67.100000</td>
#       <td id="T_d6465_row7_col6" class="data row7 col6" >2.420000</td>
#       <td id="T_d6465_row7_col7" class="data row7 col7" >81.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head(10).style.bar(axis=0)
# Out:
# <style type="text/css">
# #T_73a5b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.0%, transparent 60.0%);
# }
# #T_73a5b_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.1%, transparent 75.1%);
# }
# #T_73a5b_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.0%, transparent 75.0%);
# }
# #T_73a5b_row0_col3, #T_73a5b_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.8%, transparent 77.8%);
# }
# #T_73a5b_row0_col4, #T_73a5b_row1_col4, #T_73a5b_row1_col8, #T_73a5b_row2_col3, #T_73a5b_row2_col4, #T_73a5b_row3_col8, #T_73a5b_row4_col0, #T_73a5b_row5_col3, #T_73a5b_row5_col4, #T_73a5b_row5_col8, #T_73a5b_row7_col2, #T_73a5b_row7_col3, #T_73a5b_row7_col4, #T_73a5b_row7_col8, #T_73a5b_row9_col3, #T_73a5b_row9_col4, #T_73a5b_row9_col5 {
#   width: 10em;
# }
# #T_73a5b_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.0%, transparent 78.0%);
# }
# #T_73a5b_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.4%, transparent 27.4%);
# }
# #T_73a5b_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.6%, transparent 92.6%);
# }
# #T_73a5b_row0_col8, #T_73a5b_row2_col8, #T_73a5b_row4_col5, #T_73a5b_row4_col6, #T_73a5b_row4_col8, #T_73a5b_row6_col8, #T_73a5b_row7_col0, #T_73a5b_row8_col1, #T_73a5b_row8_col3, #T_73a5b_row8_col4, #T_73a5b_row8_col8, #T_73a5b_row9_col2, #T_73a5b_row9_col7, #T_73a5b_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_73a5b_row1_col0, #T_73a5b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.0%, transparent 10.0%);
# }
# #T_73a5b_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.1%, transparent 43.1%);
# }
# #T_73a5b_row1_col2, #T_73a5b_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.8%, transparent 68.8%);
# }
# #T_73a5b_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.4%, transparent 64.4%);
# }
# #T_73a5b_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 61.7%, transparent 61.7%);
# }
# #T_73a5b_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.3%, transparent 15.3%);
# }
# #T_73a5b_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.4%, transparent 57.4%);
# }
# #T_73a5b_row2_col0, #T_73a5b_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.0%, transparent 80.0%);
# }
# #T_73a5b_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.9%, transparent 92.9%);
# }
# #T_73a5b_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.7%, transparent 66.7%);
# }
# #T_73a5b_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.1%, transparent 54.1%);
# }
# #T_73a5b_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.4%, transparent 29.4%);
# }
# #T_73a5b_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.3%, transparent 59.3%);
# }
# #T_73a5b_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 45.2%, transparent 45.2%);
# }
# #T_73a5b_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.1%, transparent 51.1%);
# }
# #T_73a5b_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.3%, transparent 17.3%);
# }
# #T_73a5b_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.2%, transparent 65.2%);
# }
# #T_73a5b_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.3%, transparent 7.3%);
# }
# #T_73a5b_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.9%, transparent 38.9%);
# }
# #T_73a5b_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.5%, transparent 69.5%);
# }
# #T_73a5b_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.7%, transparent 41.7%);
# }
# #T_73a5b_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.9%, transparent 30.9%);
# }
# #T_73a5b_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 61.1%, transparent 61.1%);
# }
# #T_73a5b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_73a5b_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_73a5b_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.1%, transparent 77.1%);
# }
# #T_73a5b_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.4%, transparent 59.4%);
# }
# #T_73a5b_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.8%, transparent 8.8%);
# }
# #T_73a5b_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.6%, transparent 55.6%);
# }
# #T_73a5b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.0%, transparent 30.0%);
# }
# #T_73a5b_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.6%, transparent 39.6%);
# }
# #T_73a5b_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 52.1%, transparent 52.1%);
# }
# #T_73a5b_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.1%, transparent 71.1%);
# }
# #T_73a5b_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.2%, transparent 16.2%);
# }
# #T_73a5b_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.9%, transparent 71.9%);
# }
# #T_73a5b_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.8%, transparent 10.8%);
# }
# #T_73a5b_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.1%, transparent 48.1%);
# }
# #T_73a5b_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.4%, transparent 58.4%);
# }
# #T_73a5b_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.9%, transparent 81.9%);
# }
# #T_73a5b_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.9%, transparent 5.9%);
# }
# #T_73a5b_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 53.7%, transparent 53.7%);
# }
# #T_73a5b_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.0%, transparent 20.0%);
# }
# #T_73a5b_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.9%, transparent 72.9%);
# }
# #T_73a5b_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 70.8%, transparent 70.8%);
# }
# #T_73a5b_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.9%, transparent 6.9%);
# }
# #T_73a5b_row8_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.1%, transparent 98.1%);
# }
# #T_73a5b_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 63.5%, transparent 63.5%);
# }
# #T_73a5b_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.1%, transparent 10.1%);
# }
# </style>
# <table id="T_73a5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73a5b_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_73a5b_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_73a5b_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_73a5b_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_73a5b_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_73a5b_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_73a5b_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_73a5b_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_73a5b_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73a5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73a5b_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_73a5b_row0_col1" class="data row0 col1" >148</td>
#       <td id="T_73a5b_row0_col2"

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
print("dimension of diabetes data: {}".format(df.shape))
# Out:
# dimension of diabetes data: (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
#  * Dataset is small and well labeled. There are no null values present.
#  * very suitable to supervised machine learning formulation.
#  * This is a binary classification problem, where we have 2 classes in the target **(y)** (i.e.`df['Outcome']`) and the medical conditions can be used as the feature (**X**).

# %% [markdown]
# ## Pairplot of the all the features

# %%
sns.pairplot(df.iloc[:,:-1], diag_kind='hist')

# %% [markdown]
# ## Pearson correlation and feature selection

# %%
plt.figure(figsize=(10,7))
corr_mat = df.iloc[:,:-1].corr()
sns.heatmap(corr_mat, fmt='0.2f', annot=True, lw=2, cbar_kws={'label':'Pearson Correlation (r)'})
plt.xticks(size=15,rotation=90)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('Correlation.png',dpi=300);

# %% [markdown]
# * All the features hold very little correlation amongst each other. Only age and pregnancies shows a significant  strong correlation. Therefore, keeping the all the features.

# %% [markdown]
# ## Class distribution in Diabetes dataset

# %%
plt.figure(figsize=(5,5))
sns.countplot(df['Outcome'],label='Count')
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Outcome',size=15)
plt.xlabel('Count',size=15)
sns.despine(top=True)
plt.title('Class distribution',size=26, weight='bold')
plt.tight_layout()
plt.savefig('Class-distribution.png');

# %% [markdown]
# # Preparing data for machine learning

# %%
X = df.iloc[:,:-1].values   ##features selection
y = df.iloc[:,-1].values    ## target selection

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=27)

# %% [markdown]
# * It is importannt to use stratify inside **train_test_split**. It keeps the same distribution of target same  within train and testing datasets. if variable `y` is a binary categorical variable with values 0 and 1 and there are 25% of zeros and 75% of ones, `stratify=y` will make sure that random split has 40% of 0's and 60% of 1's

# %% [markdown]
# # Machine learning Models

# %% [markdown]
# ## k-Nearest Neighbors (KNN)

# %%
training_accuracy = [] 
test_accuracy = []
training_f1 = []
test_f1 = []

neighbors_settings = range(2,20)

for n_neighbors in neighbors_settings:
    print(f'working on neighbors {n_neighbors}')
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(X_train, y_train)
    
    y_train_pred=knn.predict(X_train)
    y_pred=knn.predict(X_test)
    
    training_accuracy.append(accuracy_score(y_train,y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_pred))
    
    training_f1.append(f1_score(y_train,y_train_pred))
    test_f1.append(f1_score(y_test, y_pred))
# Out:
# working on neighbors 2
# working on neighbors 3
# working on neighbors 4
# working on neighbors 5
# working on neighbors 6
# working on neighbors 7
# working on neighbors 8
# working on neighbors 9
# working on neighbors 10
# working on neighbors 11
# working on neighbors 12
# working on neighbors 13
# working on neighbors 14
# working on neighbors 15
# working on neighbors 16
# working on neighbors 17
# working on neighbors 18
# working on neighbors 19

# %%
fig = plt.figure(figsize=(14,10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)

fig.add_subplot(2,2,1)
plt.plot(neighbors_settings, training_accuracy, label='training accuracy')
plt.plot(neighbors_settings, test_accuracy, label='test accuracy')
plt.ylabel('Accuracy',size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlabel('n_neighbors',size=20)
plt.title('Accuracy Score',size=20, weight='bold')
plt.legend([],frameon=False)

fig.add_subplot(2,2,2)
plt.plot(neighbors_settings, training_f1)
plt.plot(neighbors_settings, test_f1)
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('F1 Score',size=20)
plt.xlabel('n_neighbors',size=20)
plt.title('F1-Score',size=20,weight='bold')
plt.legend(['Training','Testing'],frameon=False, bbox_to_anchor=(0.4,-0.2), ncol=2);

# %% [markdown]
# `Accuracy score`, `F1-score` suggest that `n_neighbors=19` is the optimum choice **(by looking a testing accuracies)**.

# %%
knn = KNeighborsClassifier(n_neighbors=19).fit(X_train, y_train)
y_pred = knn.predict(X_test)

print('Accuracy of K-NN classifier on test set: {:.2f}'.format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'.format(accuracy_score(y_test, y_pred)))
print('F1-score of K-NN classifier on test set: {:.2f}'.format(f1_score(y_test, y_pred)))
# Out:
# Accuracy of K-NN classifier on test set: 0.79
# Accuracy of K-NN classifier on test set: 0.71
# F1-score of K-NN classifier on test set: 0.56

# %% [markdown]
# ### Confusion matrix

# %%
def normalized_confusion_matrix(y_test, conf_mat, model):
    _ , counts = np.unique(y_test,return_counts=True)
    conf_mat = conf_mat/counts
    plt.figure(figsize=(6,5))
    ax=sns.heatmap(conf_mat,fmt='.2f',annot=True,annot_kws={'size':20},lw=2, cbar=True, cbar_kws={'label':'% Class accuracy'})
    plt.title(f'Confusion Matrix ({model})',size=22)
    plt.xticks(size=20)
    plt.yticks(size=20)
    ax.figure.axes[-1].yaxis.label.set_size(20) ##colorbar label
    cax = plt.gcf().axes[-1]  ##colorbar ticks
    cax.tick_params(labelsize=20) ## colorbar ticks
    plt.savefig(f'confusion-matrix-{model}.png',dpi=300)

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat, 'kNN')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_knn_accuracy = cross_val_score(knn, X, y, cv=10) ##10-fold cross validation
k_fold_knn_f1 = cross_val_score(knn, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_knn_accuracy.mean().round(2)} +/- {k_fold_knn_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_knn_f1.mean().round(2)} +/- {k_fold_knn_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.75 +/- 0.06
# Average F1-score after 10 fold cross validation :0.71 +/- 0.07

# %% [markdown]
# ## Logistic Regression

# %%
plt.figure(figsize=(8,6))
Clist=[1,0.01,100]

for C in Clist : 

    logreg = LogisticRegression(C=C,solver='newton-cg').fit(X_train, y_train) #keeping C=1 a
    y_train_pred = logreg.predict(X_train)
    y_pred = logreg.predict(X_test)

    print('C : {} Training set accuracy: {:.3f}'.format(C,accuracy_score(y_train, y_train_pred)))
    print('C : {} Test set accuracy: {:.3f}'.format(C,accuracy_score(y_test, y_pred)))

    print('C : {} Training set F1-score: {:.3f}'.format(C,f1_score(y_train, y_train_pred)))
    print('C : {} Test set F1-score: {:.3f}'.format(C, f1_score(y_test, y_pred)))
    print('\n')
    
   # Assuming df has 9 columns including the target
    diabetes_features = [x for i, x in enumerate(df.columns) if i != 8]  # Exclude the last column (target)

# Use the correct number of ticks for the plot
plt.plot(logreg.coef_.T, marker='o', label=f"C={C}")
plt.xticks(range(len(diabetes_features)), diabetes_features, rotation=90)  # Adjust to match the length
plt.hlines(0, 0, len(diabetes_features) - 1)
plt.ylim(-5, 5)
# Out:
# C : 1 Training set accuracy: 0.778
# C : 1 Test set accuracy: 0.776
# C : 1 Training set F1-score: 0.646
# C : 1 Test set F1-score: 0.650
#
#
# C : 0.01 Training set accuracy: 0.776
# C : 0.01 Test set accuracy: 0.766
# C : 0.01 Training set F1-score: 0.645
# C : 0.01 Test set F1-score: 0.634
#
#
# C : 100 Training set accuracy: 0.774
# C : 100 Test set accuracy: 0.771
# C : 100 Training set F1-score: 0.641
# C : 100 Test set F1-score: 0.645
# (-5.0, 5.0)

# %% [markdown]
# The default value of C=1 provides with 78% accuracy on training and 77% accuracy on test set.

# %% [markdown]
# Stronger regularization (`C=0.001`) pushes coefficients more and more toward zero. Inspecting the plot more closely suggests that feature `DiabetesPedigreeFunction`, for `C=100`, `C=1` and `C=0.001`, the coefficient is positive. This indicates that high `DiabetesPedigreeFunctio` feature is related to a sample being`diabetes`, regardless which model we look at.

# %% [markdown]
# ### Confusion matrix

# %%
logreg = LogisticRegression(C=1,solver='newton-cg').fit(X_train,y_train)
y_pred=logreg.predict(X_test)

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Logistic Regression')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_logreg_accuracy = cross_val_score(logreg, X, y, cv=10) ##10-fold cross validation
k_fold_logreg_f1 = cross_val_score(logreg, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_logreg_accuracy.mean().round(2)} +/- {k_fold_logreg_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_logreg_f1.mean().round(2)} +/- {k_fold_logreg_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.77 +/- 0.04
# Average F1-score after 10 fold cross validation :0.74 +/- 0.04

# %% [markdown]
# ## Decision Tree

# %%
max_depth=range(1,20)
training_accuracy = [] 
test_accuracy = []
training_f1 = []
test_f1 = []

for depth in max_depth : 
    tree = DecisionTreeClassifier(random_state=0, max_depth=depth, min_samples_leaf=1).fit(X_train, y_train)
    y_train_pred = tree.predict(X_train)
    y_pred = tree.predict(X_test)
    
    training_accuracy.append(accuracy_score(y_train,y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_pred))
    
    training_f1.append(f1_score(y_train,y_train_pred))
    test_f1.append(f1_score(y_test, y_pred))

# %%
fig = plt.figure(figsize=(14,10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)

fig.add_subplot(2,2,1)
plt.plot(max_depth, training_accuracy, label='training accuracy')
plt.plot(max_depth, test_accuracy, label='test accuracy')
plt.ylabel('Accuracy',size=20)
plt.xlabel('Max depth',size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title('Accuracy Score',size=20, weight='bold')
plt.legend([],frameon=False)

fig.add_subplot(2,2,2)
plt.plot(max_depth, training_f1)
plt.plot(max_depth, test_f1)
plt.ylabel('F1 Score',size=20)
plt.xlabel('Max depth',size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title('F1-Score',size=20,weight='bold')
plt.legend(['Training','Testing'],frameon=False, bbox_to_anchor=(0.4,-0.2), ncol=2);

# %% [markdown]
# The training accuracy on the after training set is 100%, while the test set accuracy is much worse. This means tree is  overfitting and not generalizing well to new data. We set `max_depth=4`, limiting the depth of the tree decreases overfitting. This leads to a lower accuracy on the training set, but an improvement on the test set.

# %%
tree = DecisionTreeClassifier(max_depth=4, min_samples_leaf=1, random_state=0).fit(X_train, y_train)
y_pred=tree.predict(X_test)

print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on test: 0.724
# F1-score on test set: 0.624

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Decision Tree')

# %% [markdown]
# ### K-fold cross validation

# %%
k_fold_tree_accuracy = cross_val_score(tree, X, y, cv=10) ##10-fold cross validation
k_fold_tree_f1 = cross_val_score(tree, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_tree_accuracy.mean().round(2)} +/- {k_fold_tree_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_tree_f1.mean().round(2)} +/- {k_fold_tree_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.72 +/- 0.04
# Average F1-score after 10 fold cross validation :0.69 +/- 0.05

# %% [markdown]
# ### Feature importance in Decision trees
# Feature importance rates how important each feature is for the decision a tree makes. It is a number between 0 and 1
#
#      0 means “not used at all”
#      1 means “perfectly predicts the target”

# %%
def plot_feature_importances(model, figure):
    n_features = 8
    plt.figure(figsize=(10,6))
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), diabetes_features,size=15)
    plt.xticks(size=15)
    plt.xlabel('Feature importance',size=20,)
    #plt.ylabel('Feature',size=20)
    plt.ylim(-1, n_features)
    sns.despine(top=True)
    plt.title(f'{figure}',size=20)
    plt.tight_layout()
    plt.savefig(f'feature-image{figure}.png',dpi=300)

plot_feature_importances(tree,'Decision Tree')

# %% [markdown]
# Feature `Glucose` is the most important feature.

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=0).fit(X_train, y_train)
y_pred=rf.predict(X_test)

print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on test: 0.740
# F1-score on test set: 0.603

# %% [markdown]
#  The default parameters of the random forest work well. This conclusion is derived after trying various values of  `max_depth` and `n_estimators`.

# %% [markdown]
# ### Feature importance in Random Forest

# %%
plot_feature_importances(rf, 'Random Forest')

# %% [markdown]
# Similarly to the single decision tree, the random forest also gives a lot of importance to the `Glucose` feature and it also chooses `BMI` to be the 2nd most informative features.

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Random Forest')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_rf_accuracy = cross_val_score(rf, X, y, cv=10) ##10-fold cross validation
k_fold_rf_f1 = cross_val_score(rf, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_tree_accuracy.mean().round(2)} +/- {k_fold_tree_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_tree_f1.mean().round(2)} +/- {k_fold_tree_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.72 +/- 0.04
# Average F1-score after 10 fold cross validation :0.69 +/- 0.05

# %% [markdown]
# ## Gradient Boosting

# %%
gb = GradientBoostingClassifier(random_state=0, max_depth=1, learning_rate=0.01).fit(X_train, y_train)
y_pred=gb.predict(X_test)

print("Accuracy on train: {:.3f}".format(gb.score(X_train, y_train)))
print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.750
# Accuracy on test: 0.734
# F1-score on test set: 0.463

# %% [markdown]
# Default values result in **overfitting**. Therefore, `max_depth = 1` and `learning_rate = 0.01` is chosen which reduces the gap between training and test accuracy.

# %% [markdown]
# ### Feature importance in Gradient Boosting

# %%
plot_feature_importances(gb, 'Gradient Boosting')

# %% [markdown]
# Gradient Boosting gives the most importance to `Glucose`.

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Gradient Boosting')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_gb_accuracy = cross_val_score(gb, X, y, cv=10) ##10-fold cross validation
k_fold_gb_f1 = cross_val_score(gb, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation :{k_fold_gb_accuracy.mean().round(2)} +/- {k_fold_gb_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation :{k_fold_gb_f1.mean().round(2)} +/- {k_fold_gb_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation :0.75 +/- 0.03
# Average F1-score after 10 fold cross validation :0.67 +/- 0.03

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

#SVM requiest feature scaling
svc = SVC(C=1000, gamma='auto').fit(X_train_scaled, y_train)
y_pred=svc.predict(X_test_scaled)

print("Accuracy on train: {:.3f}".format(svc.score(X_train_scaled, y_train)))
print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.811
# Accuracy on test: 0.719
# F1-score on test set: 0.460

# %% [markdown]
# `C = 1000`, `gamma='auto'` gives the best performance and minimum **overfitting**.

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'SVM')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_svm_accuracy = cross_val_score(svc, scaler.fit_transform(X), y, cv=10) ##10-fold cross validation
k_fold_svm_f1 = cross_val_score(svc, scaler.fit_transform(X), y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation : {k_fold_svm_accuracy.mean().round(2)} +/- {k_fold_svm_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation : {k_fold_svm_f1.mean().round(2)} +/- {k_fold_svm_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation : 0.76 +/- 0.03
# Average F1-score after 10 fold cross validation : 0.72 +/- 0.03

# %% [markdown]
# ## Neural Networks

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

mlp = MLPClassifier(random_state=0, alpha=1, max_iter=2000).fit(X_train_scaled, y_train)
y_pred=mlp.predict(X_test_scaled)

print("Accuracy on train: {:.3f}".format(mlp.score(X_train_scaled, y_train)))
print("Accuracy on test: {:.3f}".format(accuracy_score(y_pred, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.825
# Accuracy on test: 0.776
# F1-score on test set: 0.656

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'Neural Networks')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_mlp_accuracy = cross_val_score(mlp, scaler.fit_transform(X), y, cv=10) ##10-fold cross validation
k_fold_mlp_f1 = cross_val_score(mlp, scaler.fit_transform(X), y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation : {k_fold_mlp_accuracy.mean().round(2)} +/- {k_fold_mlp_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation : {k_fold_mlp_f1.mean().round(2)} +/- {k_fold_mlp_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation : 0.77 +/- 0.04
# Average F1-score after 10 fold cross validation : 0.73 +/- 0.04

# %% [markdown]
# ## XGBoost

# %%
xgb = XGBClassifier(random_state=0, learning_rate =0.01,n_estimators=100, max_depth=5,gamma=1).fit(X_train,y_train)

y_pred=xgb.predict(X_test)

print("Accuracy on train: {:.3f}".format(xgb.score(X_train, y_train)))
print("Accuracy on test: {:.3f}".format(xgb.score(X_test, y_test)))
print("F1-score on test set: {:.3f}".format(f1_score(y_pred, y_test)))
# Out:
# Accuracy on train: 0.845
# Accuracy on test: 0.771
# F1-score on test set: 0.600

# %% [markdown]
# ### Confusion matrix

# %%
conf_mat = confusion_matrix(y_test,y_pred)
normalized_confusion_matrix(y_test,conf_mat,'XGBoost')

# %% [markdown]
# ### K-fold cross-validation

# %%
k_fold_xgb_accuracy = cross_val_score(xgb, X, y, cv=10) ##10-fold cross validation
k_fold_xgb_f1 = cross_val_score(xgb, X, y, cv=10, scoring='f1_macro') ##10-fold cross validation

# %%
print(f'Average accuracy after 10 fold cross validation : {k_fold_xgb_accuracy.mean().round(2)} +/- {k_fold_xgb_accuracy.std().round(2)}')
print(f'Average F1-score after 10 fold cross validation : {k_fold_xgb_f1.mean().round(2)} +/- {k_fold_xgb_f1.std().round(2)}')
# Out:
# Average accuracy after 10 fold cross validation : 0.75 +/- 0.04
# Average F1-score after 10 fold cross validation : 0.69 +/- 0.06

# %% [markdown]
# ### Feature importance in XGBoost

# %%
plot_feature_importances(xgb, 'XGBoost')

# %% [markdown]
# # Model comparision

# %%
all_accuracies = [k_fold_knn_accuracy.mean().round(2),
                   k_fold_logreg_accuracy.mean().round(2),
                   k_fold_tree_accuracy.mean().round(2),
                   k_fold_rf_accuracy.mean().round(2),
                   k_fold_gb_accuracy.mean().round(2),
                   k_fold_svm_accuracy.mean().round(2),
                   k_fold_mlp_accuracy.mean().round(2),
                   k_fold_xgb_accuracy.mean().round(2)]

all_accuracies_errors = [k_fold_knn_accuracy.std().round(2),
                   k_fold_logreg_accuracy.std().round(2),
                   k_fold_tree_accuracy.std().round(2),
                   k_fold_rf_accuracy.std().round(2),
                   k_fold_gb_accuracy.std().round(2),
                   k_fold_svm_accuracy.std().round(2),
                   k_fold_mlp_accuracy.std().round(2),
                   k_fold_xgb_accuracy.std().round(2)]

# %%
all_f1 = [k_fold_knn_accuracy.mean().round(2),
                   k_fold_logreg_f1.mean().round(2),
                   k_fold_tree_f1.mean().round(2),
                   k_fold_rf_f1.mean().round(2),
                   k_fold_gb_f1.mean().round(2),
                   k_fold_svm_f1.mean().round(2),
                   k_fold_mlp_f1.mean().round(2),
                   k_fold_xgb_f1.mean().round(2)]

all_f1_errors = [k_fold_knn_f1.std().round(2),
                   k_fold_logreg_f1.std().round(2),
                   k_fold_tree_f1.std().round(2),
                   k_fold_rf_f1.std().round(2),
                   k_fold_gb_f1.std().round(2),
                   k_fold_svm_f1.std().round(2),
                   k_fold_mlp_f1.std().round(2),
                   k_fold_xgb_f1.std().round(2)]

# %%
models=['kNN','Logistic Regression','Decision Tree','Random Forest','Gradient Boosting','SVM','Neural Networks', 'XGBoost']

# %%
model_data = pd.DataFrame([all_accuracies,all_accuracies_errors,all_f1,all_f1_errors],columns=models, index = ['Accuracy','STD_acc','F1-macro','STD_f1']).T

# %%
model_data.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style type="text/css">
# #T_d6f84_row0_col0, #T_d6f84_row4_col0, #T_d6f84_row7_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_d6f84_row0_col1, #T_d6f84_row0_col2, #T_d6f84_row0_col3, #T_d6f84_row1_col0, #T_d6f84_row3_col1, #T_d6f84_row6_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d6f84_row1_col1, #T_d6f84_row2_col1, #T_d6f84_row6_col1, #T_d6f84_row7_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_d6f84_row1_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_d6f84_row1_col3, #T_d6f84_row6_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_d6f84_row2_col0, #T_d6f84_row4_col1, #T_d6f84_row4_col2, #T_d6f84_row4_col3, #T_d6f84_row5_col1, #T_d6f84_row5_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d6f84_row2_col2, #T_d6f84_row7_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_d6f84_row2_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_d6f84_row3_col0, #T_d6f84_row5_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_d6f84_row3_col2, #T_d6f84_row3_col3, #T_d6f84_row6_col2, #T_d6f84_row7_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_d6f84_row5_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# </style>
# <table id="T_d6f84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6f84_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d6f84_level0_col1" class="col_heading level0 col1" >STD_acc</th>
#       <th id="T_d6f84_level0_col2" class="col_heading level0 col2" >F1-macro</th>
#       <th id="T_d6f84_level0_col3" class="col_heading level0 col3" >STD_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6f84_level0_row0" class="row_heading level0 row0" >kNN</th>
#       <td id="T_d6f84_row0_col0" class="data row0 col0" >0.750000</td>
#       <td id="T_d6f84_row0_col1" class="data row0 col1" >0.060000</td>
#       <td id="T_d6f84_row0_col2" class="data row0 col2" >0.750000</td>
#       <td id="T_d6f84_row0_col3" class="data row0 col3" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_d6f84_level0_row1" class="row_heading level0 row1" >Logistic Regression</th>
#       <td id="T_d6f84_row1_col0" class="data row1 col0" >0.770000</td>
#       <td id="T_d6f84_row1_col1" class="data row1 col1" >0.040000</td>
#       <td id="T_d6f84_row1_col2" class="data row1 col2" >0.740000</td>
#       <td id="T_d6f84_row1_col3" class="data row1 col3" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_d6f84_level0_row2" class="row_heading level0 row2" >Decision Tree</th>
#       <td id="T_d6f84_row2_col0" class="data row2 col0" >0.720000</td>
#       <td id="T_d6f84_row2_col1" class="data row2 col1" >0.040000</td>
#       <td id="T_d6f84_row2_col2" class="data row2 col2" >0.690000</td>
#       <td id="T_d6f84_row2_col3" class="data row2 col3" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_d6f84_level0_row3" class="row_heading level0 row3" >Random Forest</th>
#       <td id="T_d6f84_row3_col0" class="data row3 col0" >0.760000</td>
#       <td id="T_d6f84_row3_col1" class="data row3 col1" >0.060000</td>
#       <td id="T_d6f84_row3_col2" class="data row3 col2" >0.730000</td>
#       <td id="T_d6f84_row3_col3" class="data row3 col3" >0.060000</td>
#     </tr>
#     <tr>
#       <th id="T_d6f84_level0_row4" class="row_heading level0 row4" >Gradient Boosting</th>
#       <td id="T_d6f84_row4_col0" class="data row4 col0" >0.750000</td>
#       <td id="T_d6f84_row4_col1" class="data row4 col1" >0.030000</td>
#       <td id="T_d6f84_row4_col2" class="data row4 col2" >0.670000</td>
#       <td id="T_d6f84_row4_col3" class="data row4 col3" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_d6f84_level0_row5" class="row_heading level0 row5" >SVM</th>
#       <td id="T_d6f84_row5_col0" class="data row5 col0" >0.760000</td>
#       <td id="T_d6f84_row5_col1" class="data row5 col1" >0.030000</td>
#       <td id="T_d6f84_row5_col2" class="data row5 col2" >0.720000</td>
#       <td id="T_d6f84_row5_col3" class="data row5 col3" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_d6f84_level0_row6" class="row_heading level0 row6" >Neural Networks</th>
#       <td id="T_d6f84_row6_col0" class="data row6 col0" >0.770000</td>
#       <td id="T_d6f84_row6_col1" class="data row6 col1" >0.040000</td>
#       <td id="T_d6f84_row6_col2" class="data row6 col2" >0.730000</td>
#       <td id="T_d6f84_row6_col3" class="data row6 col3" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_d6f84_level0_row7" class="row_heading level0 row7" >XGBoost</th>
#       <td id="T_d6f84_row7_col0" class="data row7 col0" >0.750000</td>
#       <td id="T_d6f84_row7_col1" class="data row7 col1" >0.040000</td>
#       <td id="T_d6f84_row7_col2" class="data row7 col2" >0.690000</td>
#       <td id="T_d6f84_row7_col3" class="data row7 col3" >0.060000</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_data[['Accuracy','F1-macro']].plot.barh(figsize=(10,7))
plt.legend(frameon=False,bbox_to_anchor=(0.7,0.8), prop={'size':20})
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlim([0.65,0.8]);
plt.title('Model performances',size=20)
sns.despine(top=True)
plt.tight_layout()
plt.savefig('model-comparision.png',dpi=300)

# %%
plt.figure(figsize=(10,7))
diabetes_accuracy = [0.52, 0.60, 0.66, 0.57, 0.33, 0.34, 0.61, 0.64]
plt.barh(models,diabetes_accuracy, color='red',alpha=0.5)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title('Accuracy in Diabetes Detection',size=20)
sns.despine(top=True)
plt.tight_layout()
plt.savefig('diabetes-detection.png',dpi=300)

# %% [markdown]
# -- Save the model

# %%
import pickle

# Save the Logistic Regression model
with open('logistic_regression_model.pkl', 'wb') as f:
    pickle.dump(logreg, f)

print("Logistic Regression model saved successfully!")
# Out:
# Logistic Regression model saved successfully!

# %% [markdown]
# # Conclusion

# %% [markdown]
# * **Logistic regression** and **Neural Netowrks** seems to provide the best performance based on **10-fold cross validation** of the dataset. **Logistic regression** achieves a higher *F1-score* as well, which is better metric for model evalution.
# * From the confusion matricies, decision tree has the highest success in detecting the diabetes.
# * **Feature selection** suggests the `Glucose` is the most crucial factor for the successful prediction of diabetes.

# %% [markdown]
# #  In Future

# %% [markdown]
# * More hyperparameter tuning.
# * More classifiers such as `catboost` to improve the performance.
# * Generating a Tableau Dashboard
